# %% [markdown]
# # Analysis on COMPAS Recidivism Data
# ### By: Tyler Rosselli, Kyle Mettler, Ethan Wong

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(30,50)})

# %%
df = pd.read_csv("data/compas-scores-raw.csv")

# %%
df.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 1          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 2          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 3          Male        Caucasian    09/16/84           22  Risk and Prescreen
# 4          Male        Caucasian    09/16/84           22  Risk and Prescreen
#
#   AssessmentReason Language LegalStatus CustodyStatus MaritalStatus  \
# 0           Intake  English    Pretrial   Jail Inmate        Single
# 1           Intake  English    Pretrial   Jail Inmate        Single
# 2           Intake  English    Pretrial   Jail Inmate        Single
# 3           Intake  English    Pretrial   Jail Inmate       Married
# 4           Intake  English    Pretrial   Jail Inmate       Married
#
#   Screening_Date  RecSupervisionLevel RecSupervisionLevelText  Scale_ID  \
# 0    1/1/13 0:00                    1                     Low         7
# 1    1/1/13 0:00                    1                     Low         8
# 2    1/1/13 0:00                    1                     Low        18
# 3    1/1/13 0:00                    1                     Low         7
# 4    1/1/13 0:00                    1                     Low         8
#
#                  DisplayText  RawScore  DecileScore ScoreText AssessmentType  \
# 0           Risk of Violence     -2.08            4       Low            New
# 1         Risk of Recidivism     -1.06            2       Low            New
# 2  Risk of Failure to Appear     15.00            1       Low            New
# 3           Risk of Violence     -2.84            2       Low            New
# 4         Risk of Recidivism     -1.50            1       Low            New
#
#    IsCompleted  IsDeleted
# 0            1          0
# 1            1          0
# 2            1          0
# 3            1          0
# 4            1          0

# %% [markdown]
# ## There are no duplicates

# %%
df.shape

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape

# %% [markdown]
# ## Correct Types

# %%
df.dtypes

# %%
df.DateOfBirth = pd.to_datetime(df['DateOfBirth'])
df.Screening_Date = pd.to_datetime(df['Screening_Date'])

# %%
df.dtypes

# %% [markdown]
# ## Columns

# %%
df.columns

# %%
columns_to_drop = ['AssessmentID','Case_ID','ScaleSet_ID','IsCompleted','IsDeleted']
df = df.drop(columns_to_drop, axis=1)
df.head()

## Rename column names
# Out:
#    Person_ID Agency_Text LastName FirstName MiddleName Sex_Code_Text  \
# 0      50844    PRETRIAL   Fisher     Kevin        NaN          Male
# 1      50844    PRETRIAL   Fisher     Kevin        NaN          Male
# 2      50844    PRETRIAL   Fisher     Kevin        NaN          Male
# 3      50848    PRETRIAL  KENDALL     KEVIN        NaN          Male
# 4      50848    PRETRIAL  KENDALL     KEVIN        NaN          Male
#
#   Ethnic_Code_Text DateOfBirth            ScaleSet AssessmentReason Language  \
# 0        Caucasian    12/05/92  Risk and Prescreen           Intake  English
# 1        Caucasian    12/05/92  Risk and Prescreen           Intake  English
# 2        Caucasian    12/05/92  Risk and Prescreen           Intake  English
# 3        Caucasian    09/16/84  Risk and Prescreen           Intake  English
# 4        Caucasian    09/16/84  Risk and Prescreen           Intake  English
#
#   LegalStatus CustodyStatus MaritalStatus Screening_Date  RecSupervisionLevel  \
# 0    Pretrial   Jail Inmate        Single    1/1/13 0:00                    1
# 1    Pretrial   Jail Inmate        Single    1/1/13 0:00                    1
# 2    Pretrial   Jail Inmate        Single    1/1/13 0:00                    1
# 3    Pretrial   Jail Inmate       Married    1/1/13 0:00                    1
# 4    Pretrial   Jail Inmate       Married    1/1/13 0:00                    1
#
#   RecSupervisionLevelText  Scale_ID                DisplayText  RawScore  \
# 0                     Low         7           Risk of Violence     -2.08
# 1                     Low         8         Risk of Recidivism     -1.06
# 2                     Low        18  Risk of Failure to Appear     15.00
# 3                     Low         7           Risk of Violence     -2.84
# 4                     Low         8         Risk of Recidivism     -1.50
#
#    DecileScore ScoreText AssessmentType
# 0            4       Low            New
# 1            2       Low            New
# 2            1       Low            New
# 3            2       Low            New
# 4            1       Low            New

# %%
df.rename(columns={'Sex_Code_Text': 'Sex', 'Ethnic_Code_Text': 'Race', 'DisplayText': 'RiskType'}, inplace=True)

# %%
df.head()
# Out:
#    Person_ID Agency_Text LastName FirstName MiddleName   Sex       Race  \
# 0      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 1      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 2      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 3      50848    PRETRIAL  KENDALL     KEVIN        NaN  Male  Caucasian
# 4      50848    PRETRIAL  KENDALL     KEVIN        NaN  Male  Caucasian
#
#   DateOfBirth            ScaleSet AssessmentReason Language LegalStatus  \
# 0    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 1    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 2    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 3    09/16/84  Risk and Prescreen           Intake  English    Pretrial
# 4    09/16/84  Risk and Prescreen           Intake  English    Pretrial
#
#   CustodyStatus MaritalStatus Screening_Date  RecSupervisionLevel  \
# 0   Jail Inmate        Single    1/1/13 0:00                    1
# 1   Jail Inmate        Single    1/1/13 0:00                    1
# 2   Jail Inmate        Single    1/1/13 0:00                    1
# 3   Jail Inmate       Married    1/1/13 0:00                    1
# 4   Jail Inmate       Married    1/1/13 0:00                    1
#
#   RecSupervisionLevelText  Scale_ID                   RiskType  RawScore  \
# 0                     Low         7           Risk of Violence     -2.08
# 1                     Low         8         Risk of Recidivism     -1.06
# 2                     Low        18  Risk of Failure to Appear     15.00
# 3                     Low         7           Risk of Violence     -2.84
# 4                     Low         8         Risk of Recidivism     -1.50
#
#    DecileScore ScoreText AssessmentType
# 0            4       Low            New
# 1            2       Low            New
# 2            1       Low            New
# 3            2       Low            New
# 4            1       Low            New

# %%
df.columns
# Out:
# Index(['Person_ID', 'Agency_Text', 'LastName', 'FirstName', 'MiddleName',
#        'Sex', 'Race', 'DateOfBirth', 'ScaleSet', 'AssessmentReason',
#        'Language', 'LegalStatus', 'CustodyStatus', 'MaritalStatus',
#        'Screening_Date', 'RecSupervisionLevel', 'RecSupervisionLevelText',
#        'Scale_ID', 'RiskType', 'RawScore', 'DecileScore', 'ScoreText',
#        'AssessmentType'],
#       dtype='object')

# %% [markdown]
# ## Any Nulls?

# %%
df.isnull().sum()
# Out:
# Person_ID                      0
# Agency_Text                    0
# LastName                       0
# FirstName                      0
# MiddleName                 45195
# Sex                            0
# Race                           0
# DateOfBirth                    0
# ScaleSet                       0
# AssessmentReason               0
# Language                       0
# LegalStatus                    0
# CustodyStatus                  0
# MaritalStatus                  0
# Screening_Date                 0
# RecSupervisionLevel            0
# RecSupervisionLevelText        0
# Scale_ID                       0
# RiskType                       0
# RawScore                       0
# DecileScore                    0
# ScoreText                     45
# AssessmentType                 0
# dtype: int64

# %% [markdown]
# ## Rest of cleaning and exporting data

# %%
df[df.Race == 'African-Am'].head()
# Out:
#       Person_ID Agency_Text       LastName FirstName MiddleName   Sex  \
# 1497       4074    PRETRIAL          pratt   michael        NaN  Male
# 1498       4074    PRETRIAL          pratt   michael        NaN  Male
# 1499       4074    PRETRIAL          pratt   michael        NaN  Male
# 1668      51294   Probation  Jean Baptiste    Examon        NaN  Male
# 1669      51294   Probation  Jean Baptiste    Examon        NaN  Male
#
#             Race DateOfBirth            ScaleSet AssessmentReason Language  \
# 1497  African-Am    03/22/83  Risk and Prescreen           Intake  English
# 1498  African-Am    03/22/83  Risk and Prescreen           Intake  English
# 1499  African-Am    03/22/83  Risk and Prescreen           Intake  English
# 1668  African-Am    12/25/55  Risk and Prescreen           Intake  English
# 1669  African-Am    12/25/55  Risk and Prescreen           Intake  English
#
#         LegalStatus CustodyStatus MaritalStatus Screening_Date  \
# 1497  Post Sentence     Probation        Single   1/16/13 0:00
# 1498  Post Sentence     Probation        Single   1/16/13 0:00
# 1499  Post Sentence     Probation        Single   1/16/13 0:00
# 1668  Post Sentence     Probation        Single   1/17/13 0:00
# 1669  Post Sentence     Probation        Single   1/17/13 0:00
#
#       RecSupervisionLevel RecSupervisionLevelText  Scale_ID  \
# 1497                    4                    High         7
# 1498                    4                    High         8
# 1499                    4                    High        18
# 1668                    1                     Low         7
# 1669                    1                     Low         8
#
#                        RiskType  RawScore  DecileScore ScoreText  \
# 1497           Risk of Violence     -0.67            9      High
# 1498         Risk of Recidivism      0.83           10      High
# 1499  Risk of Failure to Appear     24.00            6    Medium
# 1668           Risk of Violence     -4.12            1       Low
# 1669         Risk of Recidivism     -1.58            1       Low
#
#      AssessmentType
# 1497            New
# 1498            New
# 1499            New
# 1668            New
# 1669            New

# %%
df.Race = df.Race.replace({
    'African-Am':'African-American'
})

# %%
df.head()
# Out:
#    Person_ID Agency_Text LastName FirstName MiddleName   Sex       Race  \
# 0      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 1      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 2      50844    PRETRIAL   Fisher     Kevin        NaN  Male  Caucasian
# 3      50848    PRETRIAL  KENDALL     KEVIN        NaN  Male  Caucasian
# 4      50848    PRETRIAL  KENDALL     KEVIN        NaN  Male  Caucasian
#
#   DateOfBirth            ScaleSet AssessmentReason Language LegalStatus  \
# 0    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 1    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 2    12/05/92  Risk and Prescreen           Intake  English    Pretrial
# 3    09/16/84  Risk and Prescreen           Intake  English    Pretrial
# 4    09/16/84  Risk and Prescreen           Intake  English    Pretrial
#
#   CustodyStatus MaritalStatus Screening_Date  RecSupervisionLevel  \
# 0   Jail Inmate        Single    1/1/13 0:00                    1
# 1   Jail Inmate        Single    1/1/13 0:00                    1
# 2   Jail Inmate        Single    1/1/13 0:00                    1
# 3   Jail Inmate       Married    1/1/13 0:00                    1
# 4   Jail Inmate       Married    1/1/13 0:00                    1
#
#   RecSupervisionLevelText  Scale_ID                   RiskType  RawScore  \
# 0                     Low         7           Risk of Violence     -2.08
# 1                     Low         8         Risk of Recidivism     -1.06
# 2                     Low        18  Risk of Failure to Appear     15.00
# 3                     Low         7           Risk of Violence     -2.84
# 4                     Low         8         Risk of Recidivism     -1.50
#
#    DecileScore ScoreText AssessmentType
# 0            4       Low            New
# 1            2       Low            New
# 2            1       Low            New
# 3            2       Low            New
# 4            1       Low            New

# %%
df.to_csv("compas-scores-clean.csv")

# %% [markdown]
# # Race vs Recidivism

# %%
#graphing data, changing non majority races to 'other'
df.Race = df.Race.replace({
    'Asian':'Other',
    'Oriental':'Other',
    'Arabic':'Other',
    'Native American':'Other'
})

# %% [markdown]
# # Decile Score

# %%
#race vs decile score
df.groupby(['Race', 'RiskType'])['DecileScore'].mean()
# Out:
# Race              RiskType
# African-American  Risk of Failure to Appear    3.368392
#                   Risk of Recidivism           5.323063
#                   Risk of Violence             4.183863
# Caucasian         Risk of Failure to Appear    3.134279
#                   Risk of Recidivism           3.587660
#                   Risk of Violence             2.602810
# Hispanic          Risk of Failure to Appear    2.671585
#                   Risk of Recidivism           3.312629
#                   Risk of Violence             2.570350
# Other             Risk of Failure to Appear    2.205910
#                   Risk of Recidivism           3.027701
#                   Risk of Violence             2.618652
# Name: DecileScore, dtype: float64

# %%
ax = sns.catplot(x='DecileScore',y='Race', col='RiskType', data=df, kind='bar', ci=False, orient='h')
ax

# %%
#distribution of decile scores across all races
#can see that african americans have the most evenly distributed decile scores
g = sns.FacetGrid(df, col='Race', col_wrap=2)
g = g.map(sns.distplot, 'DecileScore', kde=False, bins=10)

# %% [markdown]
# # Hypothesis Test 1

# %% [markdown]
# Question: Do African-Americans receive higher scores for recidivism than caucasians?

# %%
african_american = df[df.Race == 'African-American']
caucasian = df[df.Race == 'Caucasian']
african_american_scores = african_american['DecileScore']
caucasian_scores = caucasian['DecileScore']

# %%
african_american_scores.describe()
# Out:
# count    27069.000000
# mean         4.291773
# std          2.767021
# min         -1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          6.000000
# max         10.000000
# Name: DecileScore, dtype: float64

# %%
caucasian_scores.describe()
# Out:
# count    21783.000000
# mean         3.108250
# std          2.401878
# min         -1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max         10.000000
# Name: DecileScore, dtype: float64

# %%
from statsmodels.stats.weightstats import ttest_ind
from scipy import stats

# %%
tstat, pvalue, ddof = ttest_ind(
                                african_american_scores,
                                caucasian_scores,
                                alternative="larger",
                                usevar="pooled"
)

# %%
print(pvalue)
# Out:
# 0.0

# %% [markdown]
# P-value of 0, so we can reject the null hypothesis and accept the statistically proven hypothesis that African Americans receive higher scores for recidivism than Caucasians

# %% [markdown]
# # Recommended Supervision Level

# %%
#race vs recommended supervision level
df.groupby('Race')['RecSupervisionLevel'].mean()
# Out:
# Race
# African-American    1.943145
# Caucasian           1.406418
# Hispanic            1.334935
# Other               1.314866
# Name: RecSupervisionLevel, dtype: float64

# %%
ax = sns.catplot(x='RecSupervisionLevel',y='Race', data=df, kind='bar', ci=False, orient='h')

# %% [markdown]
# # Hypothesis Test 2

# %% [markdown]
# Question: Do African-Americans receive higher recommended supervision levels than caucasians?

# %%
african_american = df[df.Race == 'African-American']
caucasian = df[df.Race == 'Caucasian']
african_american_lvl = african_american['RecSupervisionLevel']
caucasian_lvl = caucasian['RecSupervisionLevel']

# %%
african_american_lvl.describe()
# Out:
# count    27069.000000
# mean         1.943145
# std          1.054442
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: RecSupervisionLevel, dtype: float64

# %%
caucasian_lvl.describe()
# Out:
# count    21783.000000
# mean         1.406418
# std          0.773997
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          4.000000
# Name: RecSupervisionLevel, dtype: float64

# %%
tstat, pvalue, ddof = ttest_ind(
                                african_american_lvl,
                                caucasian_lvl,
                                alternative="larger",
                                usevar="pooled"
)

# %%
print(pvalue)
# Out:
# 0.0

# %% [markdown]
# P-value of 0, so we can reject the null hypothesis and accept the statistically proven hypothesis that African Americans receive higher recommended supervision levels than Caucasians

# %% [markdown]
# # Linear Regression Model on compas-scores-raw

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
numerical_data = df.select_dtypes(np.number).fillna(0).drop(columns='Person_ID')
numerical_data.head()
# Out:
#    RecSupervisionLevel  Scale_ID  RawScore  DecileScore
# 0                    1         7     -2.08            4
# 1                    1         8     -1.06            2
# 2                    1        18     15.00            1
# 3                    1         7     -2.84            2
# 4                    1         8     -1.50            1

# %%
target_variable = 'DecileScore'
independent_variables = numerical_data.drop(columns = target_variable).columns

# %%
X_train, X_test, y_train, y_test = train_test_split(
     numerical_data[independent_variables],   # X
     numerical_data[target_variable], # y
     test_size=0.2,   # % of the data that goes to the test dataset
     random_state=13   # ensure reproductibility
)

# %%
print('X train', X_train.shape)
print('y train', y_train.shape)
print('X test', X_test.shape)
print('y test', y_test.shape)
# Out:
# X train (48674, 3)
# y train (48674,)
# X test (12169, 3)
# y test (12169,)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = model.predict(X_test)

# %%
X = X_test.reset_index().copy()
X["DecileScore"] = y_test.tolist()
X["prediction"] = predictions
X.head()
# Out:
#    index  RecSupervisionLevel  Scale_ID  RawScore  DecileScore  prediction
# 0   2591                    2        18     23.00            5    5.438777
# 1  21425                    2        18     23.00            5    5.438777
# 2  49445                    1        18     25.00            6    4.787859
# 3  18533                    1        18     16.00            2    1.295476
# 4  39270                    1         7     -2.32            3    3.013617

# %%
sns.relplot(x="DecileScore", y="prediction", data=X, kind="scatter")

# %%
sns.scatterplot(x=X["RecSupervisionLevel"], y=X["DecileScore"], label = 'True')
sns.scatterplot(x=X["RecSupervisionLevel"], y=X["prediction"], label = 'Predictions')
sns.mpl.pyplot.ylabel("DecileScore")
# Out:
# Text(0, 0.5, 'DecileScore')

# %% [markdown]
# # Using two year data

# %%
recid = pd.read_csv("data/compas-scores-two-years.csv")

# %%
pd.set_option('max_columns', 53)

# %%
recid.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1991-05-14   24     Less than 25  African-American              0
# 3  1993-01-21   23     Less than 25  African-American              0
# 4  1973-01-22   43          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0             1               0                0             0
# 1             3               0                0             0
# 2             4               0                1             4
# 3             8               1                0             1
# 4             1               0                0             2
#
#    days_b_screening_arrest            c_jail_in           c_jail_out  \
# 0                     -1.0  2013-08-13 06:03:42  2013-08-14 05:41:20
# 1                     -1.0  2013-01-26 03:45:27  2013-02-05 05:36:53
# 2                     -1.0  2013-04-13 04:58:34  2013-04-14 07:02:04
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
#    c_case_number c_offense_date c_arrest_date  c_days_from_compas  \
# 0  13011352CF10A     2013-08-13           NaN                 1.0
# 1  13001275CF10A     2013-01-26           NaN                 1.0
# 2  13005330CF10A     2013-04-13           NaN                 1.0
# 3  13000570CF10A     2013-01-12           NaN                 1.0
# 4  12014130CF10A            NaN    2013-01-09                76.0
#
#   c_charge_degree                   c_charge_desc  is_recid  r_case_number  \
# 0               F    Aggravated Assault w/Firearm         0            NaN
# 1               F  Felony Battery w/Prior Convict         1  13009779CF10A
# 2               F           Possession of Cocaine         1  13011511MM10A
# 3               F          Possession of Cannabis         0            NaN
# 4               F           arrest case no charge         0            NaN
#
#   r_charge_degree  r_days_from_arrest r_offense_date  \
# 0             NaN                 NaN            NaN
# 1            (F3)                 NaN     2013-07-05
# 2            (M1)                 0.0     2013-06-16
# 3             NaN                 NaN            NaN
# 4             NaN                 NaN            NaN
#
#                  r_charge_desc   r_jail_in  r_jail_out  violent_recid  \
# 0                          NaN         NaN         NaN            NaN
# 1  Felony Battery (Dom Strang)         NaN         NaN            NaN
# 2  Driving Under The Influence  2013-06-16  2013-06-16            NaN
# 3                          NaN         NaN         NaN            NaN
# 4                          NaN         NaN         NaN            NaN
#
#    is_violent_recid vr_case_number vr_charge_degree vr_offense_date  \
# 0                 0            NaN              NaN             NaN
# 1                 1  13009779CF10A             (F3)      2013-07-05
# 2                 0            NaN              NaN             NaN
# 3                 0            NaN              NaN             NaN
# 4                 0            NaN              NaN             NaN
#
#                 vr_charge_desc  type_of_assessment  decile_score.1 score_text  \
# 0                          NaN  Risk of Recidivism               1        Low
# 1  Felony Battery (Dom Strang)  Risk of Recidivism               3        Low
# 2                          NaN  Risk of Recidivism               4        Low
# 3                          NaN  Risk of Recidivism               8       High
# 4                          NaN  Risk of Recidivism               1        Low
#
#   screening_date v_type_of_assessment  v_decile_score v_score_text  \
# 0     2013-08-14     Risk of Violence               1          Low
# 1     2013-01-27     Risk of Violence               1          Low
# 2     2013-04-14     Risk of Violence               3          Low
# 3     2013-01-13     Risk of Violence               6       Medium
# 4     2013-03-26     Risk of Violence               1          Low
#
#   v_screening_date  in_custody out_custody  priors_count.1  start   end  \
# 0       2013-08-14  2014-07-07  2014-07-14               0      0   327
# 1       2013-01-27  2013-01-26  2013-02-05               0      9   159
# 2       2013-04-14  2013-06-16  2013-06-16               4      0    63
# 3       2013-01-13         NaN         NaN               1      0  1174
# 4       2013-03-26         NaN         NaN               2      0  1102
#
#    event  two_year_recid
# 0      0               0
# 1      1               1
# 2      0               1
# 3      0               0
# 4      0               0

# %%
recid.isnull().sum()
# Out:
# id                            0
# name                          0
# first                         0
# last                          0
# compas_screening_date         0
# sex                           0
# dob                           0
# age                           0
# age_cat                       0
# race                          0
# juv_fel_count                 0
# decile_score                  0
# juv_misd_count                0
# juv_other_count               0
# priors_count                  0
# days_b_screening_arrest     307
# c_jail_in                   307
# c_jail_out                  307
# c_case_number                22
# c_offense_date             1159
# c_arrest_date              6077
# c_days_from_compas           22
# c_charge_degree               0
# c_charge_desc                29
# is_recid                      0
# r_case_number              3743
# r_charge_degree            3743
# r_days_from_arrest         4898
# r_offense_date             3743
# r_charge_desc              3801
# r_jail_in                  4898
# r_jail_out                 4898
# violent_recid              7214
# is_violent_recid              0
# vr_case_number             6395
# vr_charge_degree           6395
# vr_offense_date            6395
# vr_charge_desc             6395
# type_of_assessment            0
# decile_score.1                0
# score_text                    0
# screening_date                0
# v_type_of_assessment          0
# v_decile_score                0
# v_score_text                  0
# v_screening_date              0
# in_custody                  236
# out_custody                 236
# priors_count.1                0
# start                         0
# end                           0
# event                         0
# two_year_recid                0
# dtype: int64

# %%
drop_columns = ['compas_screening_date', 'juv_fel_count',
                'juv_misd_count','c_case_number','vr_charge_degree',
                'vr_offense_date','vr_charge_desc','c_arrest_date',
                'r_case_number', 'vr_case_number','start',
                'juv_other_count','days_b_screening_arrest','c_days_from_compas']
recid = recid.drop(drop_columns,axis=1)

# %%
recid.shape
# Out:
# (7214, 39)

# %%
recid.drop(['violent_recid'],axis=1).head()
# Out:
#    id                name   first         last   sex         dob  age  \
# 0   1    miguel hernandez  miguel    hernandez  Male  1947-04-18   69
# 1   3         kevon dixon   kevon        dixon  Male  1982-01-22   34
# 2   4            ed philo      ed        philo  Male  1991-05-14   24
# 3   5         marcu brown   marcu        brown  Male  1993-01-21   23
# 4   6  bouthy pierrelouis  bouthy  pierrelouis  Male  1973-01-22   43
#
#            age_cat              race  decile_score  priors_count  \
# 0  Greater than 45             Other             1             0
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 4          25 - 45             Other             1             2
#
#              c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0  2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1  2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2  2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                  NaN                  NaN     2013-01-12               F
# 4                  NaN                  NaN            NaN               F
#
#                     c_charge_desc  is_recid r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0             NaN
# 1  Felony Battery w/Prior Convict         1            (F3)
# 2           Possession of Cocaine         1            (M1)
# 3          Possession of Cannabis         0             NaN
# 4           arrest case no charge         0             NaN
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN     2013-07-05  Felony Battery (Dom Strang)         NaN
# 2                 0.0     2013-06-16  Driving Under The Influence  2013-06-16
# 3                 NaN            NaN                          NaN         NaN
# 4                 NaN            NaN                          NaN         NaN
#
#    r_jail_out  is_violent_recid  type_of_assessment  decile_score.1  \
# 0         NaN                 0  Risk of Recidivism               1
# 1         NaN                 1  Risk of Recidivism               3
# 2  2013-06-16                 0  Risk of Recidivism               4
# 3         NaN                 0  Risk of Recidivism               8
# 4         NaN                 0  Risk of Recidivism               1
#
#   score_text screening_date v_type_of_assessment  v_decile_score v_score_text  \
# 0        Low     2013-08-14     Risk of Violence               1          Low
# 1        Low     2013-01-27     Risk of Violence               1          Low
# 2        Low     2013-04-14     Risk of Violence               3          Low
# 3       High     2013-01-13     Risk of Violence               6       Medium
# 4        Low     2013-03-26     Risk of Violence               1          Low
#
#   v_screening_date  in_custody out_custody  priors_count.1   end  event  \
# 0       2013-08-14  2014-07-07  2014-07-14               0   327      0
# 1       2013-01-27  2013-01-26  2013-02-05               0   159      1
# 2       2013-04-14  2013-06-16  2013-06-16               4    63      0
# 3       2013-01-13         NaN         NaN               1  1174      0
# 4       2013-03-26         NaN         NaN               2  1102      0
#
#    two_year_recid
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0

# %%
recid.dtypes.head()
# Out:
# id        int64
# name     object
# first    object
# last     object
# sex      object
# dtype: object

# %%
recid.dob = pd.to_datetime(recid['dob'])
recid.c_offense_date = pd.to_datetime(recid['c_offense_date'])

# %%
recid.dtypes.head()
# Out:
# id        int64
# name     object
# first    object
# last     object
# sex      object
# dtype: object

# %%
recid.shape
# Out:
# (7214, 39)

# %%
recid.to_csv('compas-scores-two-years-clean')

# %% [markdown]
# ### Calculate Average Decile Score

# %%
recid['Ave_score'] =(recid['v_decile_score']+recid['decile_score']+recid['decile_score.1'])/3

# %%
recid = recid.drop_duplicates(keep='first')

# %%
recid.shape
# Out:
# (7214, 40)

# %%
recid.head()
# Out:
#    id                name   first         last   sex        dob  age  \
# 0   1    miguel hernandez  miguel    hernandez  Male 1947-04-18   69
# 1   3         kevon dixon   kevon        dixon  Male 1982-01-22   34
# 2   4            ed philo      ed        philo  Male 1991-05-14   24
# 3   5         marcu brown   marcu        brown  Male 1993-01-21   23
# 4   6  bouthy pierrelouis  bouthy  pierrelouis  Male 1973-01-22   43
#
#            age_cat              race  decile_score  priors_count  \
# 0  Greater than 45             Other             1             0
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 4          25 - 45             Other             1             2
#
#              c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0  2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1  2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2  2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                  NaN                  NaN     2013-01-12               F
# 4                  NaN                  NaN            NaT               F
#
#                     c_charge_desc  is_recid r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0             NaN
# 1  Felony Battery w/Prior Convict         1            (F3)
# 2           Possession of Cocaine         1            (M1)
# 3          Possession of Cannabis         0             NaN
# 4           arrest case no charge         0             NaN
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN     2013-07-05  Felony Battery (Dom Strang)         NaN
# 2                 0.0     2013-06-16  Driving Under The Influence  2013-06-16
# 3                 NaN            NaN                          NaN         NaN
# 4                 NaN            NaN                          NaN         NaN
#
#    r_jail_out  violent_recid  is_violent_recid  type_of_assessment  \
# 0         NaN            NaN                 0  Risk of Recidivism
# 1         NaN            NaN                 1  Risk of Recidivism
# 2  2013-06-16            NaN                 0  Risk of Recidivism
# 3         NaN            NaN                 0  Risk of Recidivism
# 4         NaN            NaN                 0  Risk of Recidivism
#
#    decile_score.1 score_text screening_date v_type_of_assessment  \
# 0               1        Low     2013-08-14     Risk of Violence
# 1               3        Low     2013-01-27     Risk of Violence
# 2               4        Low     2013-04-14     Risk of Violence
# 3               8       High     2013-01-13     Risk of Violence
# 4               1        Low     2013-03-26     Risk of Violence
#
#    v_decile_score v_score_text v_screening_date  in_custody out_custody  \
# 0               1          Low       2013-08-14  2014-07-07  2014-07-14
# 1               1          Low       2013-01-27  2013-01-26  2013-02-05
# 2               3          Low       2013-04-14  2013-06-16  2013-06-16
# 3               6       Medium       2013-01-13         NaN         NaN
# 4               1          Low       2013-03-26         NaN         NaN
#
#    priors_count.1   end  event  two_year_recid  Ave_score
# 0               0   327      0               0   1.000000
# 1               0   159      1               1   2.333333
# 2               4    63      0               1   3.666667
# 3               1  1174      0               0   7.333333
# 4               2  1102      0               0   1.000000

# %%
recid.groupby('race')[['two_year_recid']].mean()
# Out:
#                   two_year_recid
# race
# African-American        0.514340
# Asian                   0.281250
# Caucasian               0.393643
# Hispanic                0.364207
# Native American         0.555556
# Other                   0.352785

# %%
recid.head()
# Out:
#    id                name   first         last   sex        dob  age  \
# 0   1    miguel hernandez  miguel    hernandez  Male 1947-04-18   69
# 1   3         kevon dixon   kevon        dixon  Male 1982-01-22   34
# 2   4            ed philo      ed        philo  Male 1991-05-14   24
# 3   5         marcu brown   marcu        brown  Male 1993-01-21   23
# 4   6  bouthy pierrelouis  bouthy  pierrelouis  Male 1973-01-22   43
#
#            age_cat              race  decile_score  priors_count  \
# 0  Greater than 45             Other             1             0
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 4          25 - 45             Other             1             2
#
#              c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0  2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1  2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2  2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                  NaN                  NaN     2013-01-12               F
# 4                  NaN                  NaN            NaT               F
#
#                     c_charge_desc  is_recid r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0             NaN
# 1  Felony Battery w/Prior Convict         1            (F3)
# 2           Possession of Cocaine         1            (M1)
# 3          Possession of Cannabis         0             NaN
# 4           arrest case no charge         0             NaN
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN     2013-07-05  Felony Battery (Dom Strang)         NaN
# 2                 0.0     2013-06-16  Driving Under The Influence  2013-06-16
# 3                 NaN            NaN                          NaN         NaN
# 4                 NaN            NaN                          NaN         NaN
#
#    r_jail_out  violent_recid  is_violent_recid  type_of_assessment  \
# 0         NaN            NaN                 0  Risk of Recidivism
# 1         NaN            NaN                 1  Risk of Recidivism
# 2  2013-06-16            NaN                 0  Risk of Recidivism
# 3         NaN            NaN                 0  Risk of Recidivism
# 4         NaN            NaN                 0  Risk of Recidivism
#
#    decile_score.1 score_text screening_date v_type_of_assessment  \
# 0               1        Low     2013-08-14     Risk of Violence
# 1               3        Low     2013-01-27     Risk of Violence
# 2               4        Low     2013-04-14     Risk of Violence
# 3               8       High     2013-01-13     Risk of Violence
# 4               1        Low     2013-03-26     Risk of Violence
#
#    v_decile_score v_score_text v_screening_date  in_custody out_custody  \
# 0               1          Low       2013-08-14  2014-07-07  2014-07-14
# 1               1          Low       2013-01-27  2013-01-26  2013-02-05
# 2               3          Low       2013-04-14  2013-06-16  2013-06-16
# 3               6       Medium       2013-01-13         NaN         NaN
# 4               1          Low       2013-03-26         NaN         NaN
#
#    priors_count.1   end  event  two_year_recid  Ave_score
# 0               0   327      0               0   1.000000
# 1               0   159      1               1   2.333333
# 2               4    63      0               1   3.666667
# 3               1  1174      0               0   7.333333
# 4               2  1102      0               0   1.000000

# %%
recid[recid.race == 'African-American']
# Out:
#          id             name     first     last     sex        dob  age  \
# 1         3      kevon dixon     kevon    dixon    Male 1982-01-22   34
# 2         4         ed philo        ed    philo    Male 1991-05-14   24
# 3         5      marcu brown     marcu    brown    Male 1993-01-21   23
# 11       15   ellyaher lanza  ellyaher    lanza    Male 1992-08-18   23
# 13       18     jarrod turbe    jarrod    turbe    Male 1974-12-02   41
# ...     ...              ...       ...      ...     ...        ...  ...
# 7207  10994     jarred payne    jarred    payne    Male 1985-07-31   30
# 7208  10995     raheem smith    raheem    smith    Male 1995-06-28   20
# 7209  10996    steven butler    steven   butler    Male 1992-07-17   23
# 7210  10997  malcolm simmons   malcolm  simmons    Male 1993-03-25   23
# 7212  11000      farrah jean    farrah     jean  Female 1982-11-17   33
#
#            age_cat              race  decile_score  priors_count  \
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 11    Less than 25  African-American             6             3
# 13         25 - 45  African-American             4             0
# ...            ...               ...           ...           ...
# 7207       25 - 45  African-American             2             0
# 7208  Less than 25  African-American             9             0
# 7209  Less than 25  African-American             7             0
# 7210  Less than 25  African-American             3             0
# 7212       25 - 45  African-American             2             3
#
#                 c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 1     2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2     2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                     NaN                  NaN     2013-01-12               F
# 11    2013-10-03 04:07:35  2013-10-07 08:17:30     2013-10-03               M
# 13    2013-10-08 11:53:09  2013-10-09 02:16:51     2013-10-08               F
# ...                   ...                  ...            ...             ...
# 7207  2014-05-09 10:01:33  2014-05-10 08:28:12     2014-05-09               M
# 7208  2013-10-19 11:17:15  2013-10-20 08:13:06     2013-10-19               F
# 7209  2013-11-22 05:18:27  2013-11-24 02:59:20     2013-11-22               F
# 7210  2014-01-31 07:13:54  2014-02-02 04:03:52     2014-01-31               F
# 7212  2014-03-08 08:06:02  2014-03-09 12:18:04     2014-03-08               M
#
#                           c_charge_desc  is_recid r_charge_degree  \
# 1        Felony Battery w/Prior Convict         1            (F3)
# 2                 Possession of Cocaine         1            (M1)
# 3                Possession of Cannabis         0             NaN
# 11                              Battery         1            (M2)
# 13       Poss3,4 Methylenedioxymethcath         0             NaN
# ...                                 ...       ...             ...
# 7207  Possess Cannabis/20 Grams Or Less         1            (F3)
# 7208              Possession of Cocaine         0             NaN
# 7209                   Deliver Cannabis         0             NaN
# 7210      Leaving the Scene of Accident         0             NaN
# 7212      Battery on Law Enforc Officer         0             NaN
#
#       r_days_from_arrest r_offense_date                r_charge_desc  \
# 1                    NaN     2013-07-05  Felony Battery (Dom Strang)
# 2                    0.0     2013-06-16  Driving Under The Influence
# 3                    NaN            NaN                          NaN
# 11                   NaN     2014-02-08    Driving License Suspended
# 13                   NaN            NaN                          NaN
# ...                  ...            ...                          ...
# 7207                 1.0     2015-10-21       Possession of Cannabis
# 7208                 NaN            NaN                          NaN
# 7209                 NaN            NaN                          NaN
# 7210                 NaN            NaN                          NaN
# 7212                 NaN            NaN                          NaN
#
#        r_jail_in  r_jail_out  violent_recid  is_violent_recid  \
# 1            NaN         NaN            NaN                 1
# 2     2013-06-16  2013-06-16            NaN                 0
# 3            NaN         NaN            NaN                 0
# 11           NaN         NaN            NaN                 0
# 13           NaN         NaN            NaN                 0
# ...          ...         ...            ...               ...
# 7207  2015-10-22  2015-10-22            NaN                 0
# 7208         NaN         NaN            NaN                 0
# 7209         NaN         NaN            NaN                 0
# 7210         NaN         NaN            NaN                 0
# 7212         NaN         NaN            NaN                 0
#
#       type_of_assessment  decile_score.1 score_text screening_date  \
# 1     Risk of Recidivism               3        Low     2013-01-27
# 2     Risk of Recidivism               4        Low     2013-04-14
# 3     Risk of Recidivism               8       High     2013-01-13
# 11    Risk of Recidivism               6     Medium     2013-10-03
# 13    Risk of Recidivism               4        Low     2013-10-09
# ...                  ...             ...        ...            ...
# 7207  Risk of Recidivism               2        Low     2014-05-10
# 7208  Risk of Recidivism               9       High     2013-10-20
# 7209  Risk of Recidivism               7     Medium     2013-11-23
# 7210  Risk of Recidivism               3        Low     2014-02-01
# 7212  Risk of Recidivism               2        Low     2014-03-09
#
#      v_type_of_assessment  v_decile_score v_score_text v_screening_date  \
# 1        Risk of Violence               1          Low       2013-01-27
# 2        Risk of Violence               3          Low       2013-04-14
# 3        Risk of Violence               6       Medium       2013-01-13
# 11       Risk of Violence               4          Low       2013-10-03
# 13       Risk of Violence               2          Low       2013-10-09
# ...                   ...             ...          ...              ...
# 7207     Risk of Violence               2          Low       2014-05-10
# 7208     Risk of Violence               9         High       2013-10-20
# 7209     Risk of Violence               5       Medium       2013-11-23
# 7210     Risk of Violence               5       Medium       2014-02-01
# 7212     Risk of Violence               2          Low       2014-03-09
#
#       in_custody out_custody  priors_count.1   end  event  two_year_recid  \
# 1     2013-01-26  2013-02-05               0   159      1               1
# 2     2013-06-16  2013-06-16               4    63      0               1
# 3            NaN         NaN               1  1174      0               0
# 11    2013-10-03  2013-10-07               3   128      1               1
# 13    2013-10-08  2013-10-09               0   905      0               0
# ...          ...         ...             ...   ...    ...             ...
# 7207  2015-10-22  2015-10-22               0   529      1               1
# 7208  2014-04-07  2014-04-27               0   169      0               0
# 7209  2013-11-22  2013-11-24               0   860      0               0
# 7210  2014-01-31  2014-02-02               0   790      0               0
# 7212  2014-03-08  2014-03-09               3   754      0               0
#
#       Ave_score
# 1      2.333333
# 2      3.666667
# 3      7.333333
# 11     5.333333
# 13     3.333333
# ...         ...
# 7207   2.000000
# 7208   9.000000
# 7209   6.333333
# 7210   3.666667
# 7212   2.000000
#
# [3696 rows x 40 columns]

# %%
recid.groupby('age_cat')['two_year_recid'].mean()
# Out:
# age_cat
# 25 - 45            0.459723
# Greater than 45    0.315990
# Less than 25       0.565075
# Name: two_year_recid, dtype: float64

# %% [markdown]
# ## This group by shows average decile score with average corresponding two year recid value

# %%
recid.groupby(['Ave_score'])['two_year_recid'].mean()
# Out:
# Ave_score
# 1.000000     0.203968
# 1.333333     0.271676
# 1.666667     0.298507
# 2.000000     0.312303
# 2.333333     0.340058
# 2.666667     0.368217
# 3.000000     0.375465
# 3.333333     0.392453
# 3.666667     0.399329
# 4.000000     0.396364
# 4.333333     0.480565
# 4.666667     0.535714
# 5.000000     0.539033
# 5.333333     0.567901
# 5.666667     0.513725
# 6.000000     0.573991
# 6.333333     0.605381
# 6.666667     0.601990
# 7.000000     0.658416
# 7.333333     0.664804
# 7.666667     0.728916
# 8.000000     0.688312
# 8.333333     0.676829
# 8.666667     0.720930
# 9.000000     0.746479
# 9.333333     0.761905
# 9.666667     0.805556
# 10.000000    0.750000
# Name: two_year_recid, dtype: float64

# %% [markdown]
# ### Correlation of Average Score and If they recidivated

# %%
recid['two_year_recid'].corr(recid['Ave_score'])
# Out:
# 0.35109046729878796

# %% [markdown]
# ### Hypothesis Test: Caucasian Recid vs. African American Recid

# %% [markdown]
# Question: Do afican Amercians recitivate more than caucasians?

# %%
caucasian_recid = recid[recid.race == "Caucasian"].two_year_recid
caucasian_recid
# Out:
# 6       1
# 8       0
# 9       1
# 10      0
# 12      0
#        ..
# 7192    0
# 7194    1
# 7199    0
# 7205    1
# 7206    1
# Name: two_year_recid, Length: 2454, dtype: int64

# %%
aa_recid = recid[recid.race == "African-American"].two_year_recid
aa_recid
# Out:
# 1       1
# 2       1
# 3       0
# 11      1
# 13      0
#        ..
# 7207    1
# 7208    0
# 7209    0
# 7210    0
# 7212    0
# Name: two_year_recid, Length: 3696, dtype: int64

# %%
print("AA: \n" ,aa_recid.describe())
print("Caucasian: \n", caucasian_recid.describe())
# Out:
# AA:
#  count    3696.000000
# mean        0.514340
# std         0.499862
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: two_year_recid, dtype: float64
# Caucasian:
#  count    2454.000000
# mean        0.393643
# std         0.488657
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: two_year_recid, dtype: float64

# %%
tstat, pvalue, ddof = ttest_ind(
                                caucasian_recid,
                                aa_recid                                                       
)

# %%
print(pvalue,'\n', tstat,'\n',ddof)
# Out:
# 1.1363681614743772e-20
#  -9.355920228380974
#  6148.0

# %% [markdown]
# With sucha low p value, we are able to conclude that african americans recitivate more than caucasians

# %% [markdown]
# Earlier, we found that African Americans recieve higher recidivation scores that caucasians. We have now found that they end up recitivating at a higher rate.

# %%
mid_age = recid[recid.age_cat == '25 - 45'].two_year_recid
under_25 = recid[recid.age_cat == 'Less than 25'].two_year_recid
tstat, pvalue, ddof = ttest_ind(
                                mid_age,
                                under_25                                                      
)

# %%
print(pvalue)
# Out:
# 1.7943713406031644e-12

# %%
recid.head()
# Out:
#    id                name   first         last   sex        dob  age  \
# 0   1    miguel hernandez  miguel    hernandez  Male 1947-04-18   69
# 1   3         kevon dixon   kevon        dixon  Male 1982-01-22   34
# 2   4            ed philo      ed        philo  Male 1991-05-14   24
# 3   5         marcu brown   marcu        brown  Male 1993-01-21   23
# 4   6  bouthy pierrelouis  bouthy  pierrelouis  Male 1973-01-22   43
#
#            age_cat              race  decile_score  priors_count  \
# 0  Greater than 45             Other             1             0
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 4          25 - 45             Other             1             2
#
#              c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0  2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1  2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2  2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                  NaN                  NaN     2013-01-12               F
# 4                  NaN                  NaN            NaT               F
#
#                     c_charge_desc  is_recid r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0             NaN
# 1  Felony Battery w/Prior Convict         1            (F3)
# 2           Possession of Cocaine         1            (M1)
# 3          Possession of Cannabis         0             NaN
# 4           arrest case no charge         0             NaN
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN     2013-07-05  Felony Battery (Dom Strang)         NaN
# 2                 0.0     2013-06-16  Driving Under The Influence  2013-06-16
# 3                 NaN            NaN                          NaN         NaN
# 4                 NaN            NaN                          NaN         NaN
#
#    r_jail_out  violent_recid  is_violent_recid  type_of_assessment  \
# 0         NaN            NaN                 0  Risk of Recidivism
# 1         NaN            NaN                 1  Risk of Recidivism
# 2  2013-06-16            NaN                 0  Risk of Recidivism
# 3         NaN            NaN                 0  Risk of Recidivism
# 4         NaN            NaN                 0  Risk of Recidivism
#
#    decile_score.1 score_text screening_date v_type_of_assessment  \
# 0               1        Low     2013-08-14     Risk of Violence
# 1               3        Low     2013-01-27     Risk of Violence
# 2               4        Low     2013-04-14     Risk of Violence
# 3               8       High     2013-01-13     Risk of Violence
# 4               1        Low     2013-03-26     Risk of Violence
#
#    v_decile_score v_score_text v_screening_date  in_custody out_custody  \
# 0               1          Low       2013-08-14  2014-07-07  2014-07-14
# 1               1          Low       2013-01-27  2013-01-26  2013-02-05
# 2               3          Low       2013-04-14  2013-06-16  2013-06-16
# 3               6       Medium       2013-01-13         NaN         NaN
# 4               1          Low       2013-03-26         NaN         NaN
#
#    priors_count.1   end  event  two_year_recid  Ave_score
# 0               0   327      0               0   1.000000
# 1               0   159      1               1   2.333333
# 2               4    63      0               1   3.666667
# 3               1  1174      0               0   7.333333
# 4               2  1102      0               0   1.000000

# %%
recid.head(20)
# Out:
#     id                name      first         last     sex        dob  age  \
# 0    1    miguel hernandez     miguel    hernandez    Male 1947-04-18   69
# 1    3         kevon dixon      kevon        dixon    Male 1982-01-22   34
# 2    4            ed philo         ed        philo    Male 1991-05-14   24
# 3    5         marcu brown      marcu        brown    Male 1993-01-21   23
# 4    6  bouthy pierrelouis     bouthy  pierrelouis    Male 1973-01-22   43
# 5    7        marsha miles     marsha        miles    Male 1971-08-22   44
# 6    8       edward riddle     edward       riddle    Male 1974-07-23   41
# 7    9      steven stewart     steven      stewart    Male 1973-02-25   43
# 8   10    elizabeth thieme  elizabeth       thieme  Female 1976-06-03   39
# 9   13           bo bradac         bo       bradac    Male 1994-06-10   21
# 10  14      benjamin franc   benjamin        franc    Male 1988-06-01   27
# 11  15      ellyaher lanza   ellyaher        lanza    Male 1992-08-18   23
# 12  16     kortney coleman    kortney      coleman  Female 1978-08-22   37
# 13  18        jarrod turbe     jarrod        turbe    Male 1974-12-02   41
# 14  19       craig gilbert      craig      gilbert  Female 1968-06-14   47
# 15  20     samuel seraphin     samuel     seraphin    Male 1985-03-25   31
# 16  21     mario hernandez      mario    hernandez    Male 1979-01-25   37
# 17  22      darrious davis   darrious        davis    Male 1990-06-22   25
# 18  23        neil heckart       neil      heckart    Male 1984-12-24   31
# 19  24         michael lux    michael          lux    Male 1985-01-08   31
#
#             age_cat              race  decile_score  priors_count  \
# 0   Greater than 45             Other             1             0
# 1           25 - 45  African-American             3             0
# 2      Less than 25  African-American             4             4
# 3      Less than 25  African-American             8             1
# 4           25 - 45             Other             1             2
# 5           25 - 45             Other             1             0
# 6           25 - 45         Caucasian             6            14
# 7           25 - 45             Other             4             3
# 8           25 - 45         Caucasian             1             0
# 9      Less than 25         Caucasian             3             1
# 10          25 - 45         Caucasian             4             0
# 11     Less than 25  African-American             6             3
# 12          25 - 45         Caucasian             1             0
# 13          25 - 45  African-American             4             0
# 14  Greater than 45         Caucasian             1             1
# 15          25 - 45  African-American             3             7
# 16          25 - 45          Hispanic             1             0
# 17          25 - 45  African-American            10             3
# 18          25 - 45         Caucasian             5             6
# 19          25 - 45         Caucasian             3             5
#
#               c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0   2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1   2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2   2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                   NaN                  NaN     2013-01-12               F
# 4                   NaN                  NaN            NaT               F
# 5   2013-11-30 04:50:18  2013-12-01 12:28:56     2013-11-30               M
# 6   2014-02-18 05:08:24  2014-02-24 12:18:30     2014-02-18               F
# 7   2013-08-29 08:55:23  2013-08-30 08:42:13            NaT               F
# 8   2014-03-15 05:35:34  2014-03-18 04:28:46     2014-03-15               M
# 9   2015-01-06 03:55:34  2015-01-07 03:38:44     2012-12-31               F
# 10  2013-11-25 06:31:06  2013-11-26 08:26:57     2013-11-25               F
# 11  2013-10-03 04:07:35  2013-10-07 08:17:30     2013-10-03               M
# 12  2013-01-01 03:28:03  2013-01-02 01:12:19     2013-01-01               M
# 13  2013-10-08 11:53:09  2013-10-09 02:16:51     2013-10-08               F
# 14  2013-10-10 05:12:58  2013-10-24 11:30:00            NaT               F
# 15  2014-06-25 02:15:57  2014-06-28 05:02:21     2014-03-24               F
# 16  2014-03-24 03:20:57  2014-03-24 09:09:10     2014-03-24               M
# 17  2013-12-21 05:42:02  2013-12-22 09:11:18     2013-12-21               F
# 18  2013-11-16 07:12:12  2013-11-17 08:28:54     2013-11-16               F
# 19  2014-11-14 01:37:05  2014-11-15 04:57:04     2014-11-14               F
#
#                      c_charge_desc  is_recid r_charge_degree  \
# 0     Aggravated Assault w/Firearm         0             NaN
# 1   Felony Battery w/Prior Convict         1            (F3)
# 2            Possession of Cocaine         1            (M1)
# 3           Possession of Cannabis         0             NaN
# 4            arrest case no charge         0             NaN
# 5                          Battery         0             NaN
# 6        Possession Burglary Tools         1            (F2)
# 7            arrest case no charge         0             NaN
# 8                          Battery         0             NaN
# 9                  Insurance Fraud         1            (M1)
# 10         Poss 3,4 MDMA (Ecstasy)         0             NaN
# 11                         Battery         1            (M2)
# 12                         Battery         0             NaN
# 13  Poss3,4 Methylenedioxymethcath         0             NaN
# 14           arrest case no charge         1            (F3)
# 15  Felony Driving While Lic Suspd         1            (M1)
# 16                         Battery         0             NaN
# 17   Grand Theft in the 3rd Degree         0             NaN
# 18   Driving While License Revoked         1            (F3)
# 19            Possession Of Heroin         1            (F3)
#
#     r_days_from_arrest r_offense_date                   r_charge_desc  \
# 0                  NaN            NaN                             NaN
# 1                  NaN     2013-07-05     Felony Battery (Dom Strang)
# 2                  0.0     2013-06-16     Driving Under The Influence
# 3                  NaN            NaN                             NaN
# 4                  NaN            NaN                             NaN
# 5                  NaN            NaN                             NaN
# 6                  0.0     2014-03-31  Poss of Firearm by Convic Felo
# 7                  NaN            NaN                             NaN
# 8                  NaN            NaN                             NaN
# 9                  0.0     2015-01-06                         Battery
# 10                 NaN            NaN                             NaN
# 11                 NaN     2014-02-08       Driving License Suspended
# 12                 NaN            NaN                             NaN
# 13                 NaN            NaN                             NaN
# 14                 0.0     2014-06-03     Grand Theft (Motor Vehicle)
# 15                 0.0     2014-06-25    Criminal Mischief>$200<$1000
# 16                 NaN            NaN                             NaN
# 17                 NaN            NaN                             NaN
# 18                 NaN     2014-07-16   Grand Theft in the 3rd Degree
# 19                 1.0     2015-04-27           Possession of Cocaine
#
#      r_jail_in  r_jail_out  violent_recid  is_violent_recid  \
# 0          NaN         NaN            NaN                 0
# 1          NaN         NaN            NaN                 1
# 2   2013-06-16  2013-06-16            NaN                 0
# 3          NaN         NaN            NaN                 0
# 4          NaN         NaN            NaN                 0
# 5          NaN         NaN            NaN                 0
# 6   2014-03-31  2014-04-18            NaN                 0
# 7          NaN         NaN            NaN                 0
# 8          NaN         NaN            NaN                 0
# 9   2015-01-06  2015-01-07            NaN                 1
# 10         NaN         NaN            NaN                 0
# 11         NaN         NaN            NaN                 0
# 12         NaN         NaN            NaN                 0
# 13         NaN         NaN            NaN                 0
# 14  2014-06-03  2014-11-19            NaN                 0
# 15  2014-06-25  2014-06-28            NaN                 0
# 16         NaN         NaN            NaN                 0
# 17         NaN         NaN            NaN                 0
# 18         NaN         NaN            NaN                 1
# 19  2015-04-28  2015-06-01            NaN                 0
#
#     type_of_assessment  decile_score.1 score_text screening_date  \
# 0   Risk of Recidivism               1        Low     2013-08-14
# 1   Risk of Recidivism               3        Low     2013-01-27
# 2   Risk of Recidivism               4        Low     2013-04-14
# 3   Risk of Recidivism               8       High     2013-01-13
# 4   Risk of Recidivism               1        Low     2013-03-26
# 5   Risk of Recidivism               1        Low     2013-11-30
# 6   Risk of Recidivism               6     Medium     2014-02-19
# 7   Risk of Recidivism               4        Low     2013-08-30
# 8   Risk of Recidivism               1        Low     2014-03-16
# 9   Risk of Recidivism               3        Low     2013-11-04
# 10  Risk of Recidivism               4        Low     2013-11-26
# 11  Risk of Recidivism               6     Medium     2013-10-03
# 12  Risk of Recidivism               1        Low     2013-01-01
# 13  Risk of Recidivism               4        Low     2013-10-09
# 14  Risk of Recidivism               1        Low     2013-10-30
# 15  Risk of Recidivism               3        Low     2014-06-03
# 16  Risk of Recidivism               1        Low     2014-03-24
# 17  Risk of Recidivism              10       High     2013-12-22
# 18  Risk of Recidivism               5     Medium     2013-11-17
# 19  Risk of Recidivism               3        Low     2014-11-15
#
#    v_type_of_assessment  v_decile_score v_score_text v_screening_date  \
# 0      Risk of Violence               1          Low       2013-08-14
# 1      Risk of Violence               1          Low       2013-01-27
# 2      Risk of Violence               3          Low       2013-04-14
# 3      Risk of Violence               6       Medium       2013-01-13
# 4      Risk of Violence               1          Low       2013-03-26
# 5      Risk of Violence               1          Low       2013-11-30
# 6      Risk of Violence               2          Low       2014-02-19
# 7      Risk of Violence               3          Low       2013-08-30
# 8      Risk of Violence               1          Low       2014-03-16
# 9      Risk of Violence               5       Medium       2013-11-04
# 10     Risk of Violence               4          Low       2013-11-26
# 11     Risk of Violence               4          Low       2013-10-03
# 12     Risk of Violence               1          Low       2013-01-01
# 13     Risk of Violence               2          Low       2013-10-09
# 14     Risk of Violence               1          Low       2013-10-30
# 15     Risk of Violence               2          Low       2014-06-03
# 16     Risk of Violence               1          Low       2014-03-24
# 17     Risk of Violence               9         High       2013-12-22
# 18     Risk of Violence               4          Low       2013-11-17
# 19     Risk of Violence               2          Low       2014-11-15
#
#     in_custody out_custody  priors_count.1   end  event  two_year_recid  \
# 0   2014-07-07  2014-07-14               0   327      0               0
# 1   2013-01-26  2013-02-05               0   159      1               1
# 2   2013-06-16  2013-06-16               4    63      0               1
# 3          NaN         NaN               1  1174      0               0
# 4          NaN         NaN               2  1102      0               0
# 5   2013-11-30  2013-12-01               0   853      0               0
# 6   2014-03-31  2014-04-18              14    40      1               1
# 7   2014-05-22  2014-06-03               3   265      0               0
# 8   2014-03-15  2014-03-18               0   747      0               0
# 9   2015-01-06  2015-01-07               1   428      1               1
# 10  2013-11-25  2013-11-26               0   857      0               0
# 11  2013-10-03  2013-10-07               3   128      1               1
# 12  2013-01-01  2013-01-02               0  1186      0               0
# 13  2013-10-08  2013-10-09               0   905      0               0
# 14  2014-06-03  2014-11-19               1   216      1               1
# 15  2014-06-25  2014-06-28               7    22      1               1
# 16  2014-03-24  2014-03-24               0   739      0               0
# 17  2015-03-30  2015-05-31               3   463      0               0
# 18  2013-11-16  2013-11-17               6   241      1               1
# 19  2016-02-16  2016-03-18               5   163      1               1
#
#     Ave_score
# 0    1.000000
# 1    2.333333
# 2    3.666667
# 3    7.333333
# 4    1.000000
# 5    1.000000
# 6    4.666667
# 7    3.666667
# 8    1.000000
# 9    3.666667
# 10   4.000000
# 11   5.333333
# 12   1.000000
# 13   3.333333
# 14   1.000000
# 15   2.666667
# 16   1.000000
# 17   9.666667
# 18   4.666667
# 19   2.666667

# %%
recid[recid['race'] == 'African-American'].two_year_recid.value_counts(True)
# Out:
# 1    0.51434
# 0    0.48566
# Name: two_year_recid, dtype: float64

# %%
recid[recid['race'] == 'Caucasian'].two_year_recid.value_counts(True)
# Out:
# 0    0.606357
# 1    0.393643
# Name: two_year_recid, dtype: float64

# %%
recid.head()
# Out:
#    id                name   first         last   sex        dob  age  \
# 0   1    miguel hernandez  miguel    hernandez  Male 1947-04-18   69
# 1   3         kevon dixon   kevon        dixon  Male 1982-01-22   34
# 2   4            ed philo      ed        philo  Male 1991-05-14   24
# 3   5         marcu brown   marcu        brown  Male 1993-01-21   23
# 4   6  bouthy pierrelouis  bouthy  pierrelouis  Male 1973-01-22   43
#
#            age_cat              race  decile_score  priors_count  \
# 0  Greater than 45             Other             1             0
# 1          25 - 45  African-American             3             0
# 2     Less than 25  African-American             4             4
# 3     Less than 25  African-American             8             1
# 4          25 - 45             Other             1             2
#
#              c_jail_in           c_jail_out c_offense_date c_charge_degree  \
# 0  2013-08-13 06:03:42  2013-08-14 05:41:20     2013-08-13               F
# 1  2013-01-26 03:45:27  2013-02-05 05:36:53     2013-01-26               F
# 2  2013-04-13 04:58:34  2013-04-14 07:02:04     2013-04-13               F
# 3                  NaN                  NaN     2013-01-12               F
# 4                  NaN                  NaN            NaT               F
#
#                     c_charge_desc  is_recid r_charge_degree  \
# 0    Aggravated Assault w/Firearm         0             NaN
# 1  Felony Battery w/Prior Convict         1            (F3)
# 2           Possession of Cocaine         1            (M1)
# 3          Possession of Cannabis         0             NaN
# 4           arrest case no charge         0             NaN
#
#    r_days_from_arrest r_offense_date                r_charge_desc   r_jail_in  \
# 0                 NaN            NaN                          NaN         NaN
# 1                 NaN     2013-07-05  Felony Battery (Dom Strang)         NaN
# 2                 0.0     2013-06-16  Driving Under The Influence  2013-06-16
# 3                 NaN            NaN                          NaN         NaN
# 4                 NaN            NaN                          NaN         NaN
#
#    r_jail_out  violent_recid  is_violent_recid  type_of_assessment  \
# 0         NaN            NaN                 0  Risk of Recidivism
# 1         NaN            NaN                 1  Risk of Recidivism
# 2  2013-06-16            NaN                 0  Risk of Recidivism
# 3         NaN            NaN                 0  Risk of Recidivism
# 4         NaN            NaN                 0  Risk of Recidivism
#
#    decile_score.1 score_text screening_date v_type_of_assessment  \
# 0               1        Low     2013-08-14     Risk of Violence
# 1               3        Low     2013-01-27     Risk of Violence
# 2               4        Low     2013-04-14     Risk of Violence
# 3               8       High     2013-01-13     Risk of Violence
# 4               1        Low     2013-03-26     Risk of Violence
#
#    v_decile_score v_score_text v_screening_date  in_custody out_custody  \
# 0               1          Low       2013-08-14  2014-07-07  2014-07-14
# 1               1          Low       2013-01-27  2013-01-26  2013-02-05
# 2               3          Low       2013-04-14  2013-06-16  2013-06-16
# 3               6       Medium       2013-01-13         NaN         NaN
# 4               1          Low       2013-03-26         NaN         NaN
#
#    priors_count.1   end  event  two_year_recid  Ave_score
# 0               0   327      0               0   1.000000
# 1               0   159      1               1   2.333333
# 2               4    63      0               1   3.666667
# 3               1  1174      0               0   7.333333
# 4               2  1102      0               0   1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
variables = ['is_violent_recid','decile_score.1','v_decile_score','priors_count']

# %%
target_value = ['two_year_recid']

# %%
X = recid[recid['race']=="African-American"]
Z = recid[recid['race']=="Caucasian"]
Z = Z[variables].reset_index()
X = X[variables].reset_index()

# %%
y = recid[recid['race']=="African-American"][target_value]
Y = recid[recid['race']=="Caucasian"][target_value]
aax_train, aax_test, aay_train, aay_test = train_test_split(X,y,test_size=0.2)
cx_train, cx_test, cy_train, cy_test = train_test_split(Z,Y,test_size=0.2)

# %%
Clog = LogisticRegression()
Clog.fit(cx_train, cy_train)
aalog = LogisticRegression()
aalog.fit(aax_train,aay_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
cpredictions = Clog.predict(cx_test)
aapredictions = aalog.predict(aax_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
aatrue = aay_test 
confusion_matrix(aatrue,aapredictions)
# Out:
# array([[261,  82],
#        [148, 249]])

# %%
ctrue = cy_test
confusion_matrix(ctrue,cpredictions)
# Out:
# array([[270,  33],
#        [101,  87]])

# %%
from sklearn import metrics
print("African American Accuracy:" ,metrics.accuracy_score(aatrue, aapredictions))
print("Caucasian Accuracy:" ,metrics.accuracy_score(ctrue,cpredictions))
# Out:
# African American Accuracy: 0.6891891891891891
# Caucasian Accuracy: 0.7270875763747454
